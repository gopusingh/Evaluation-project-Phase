# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df['ERA'] = df['ERA'].astype(int)

# %%
df['ERA'].dtype
# Out:
# dtype('int32')

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA   -0.133406
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df.plot(kind='box',figsize=(20,30))
# Out:
# <Axes: >

# %%
del df['E']
del df['CG']
del df['H']
del df['AB']

# %% [markdown]
# # Scaling is required

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True,fmt='.1g',annot_kws={'fontsize':20})
# Out:
# <Axes: >

# %%
x = df.drop('W',axis=1)
y = df['W']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_train)

x_train_sca = scaler.transform(x_train)
x_test_sca = scaler.transform(x_test)

x_train_sca= pd.DataFrame(x_train_sca, columns=x_train.columns)
x_test_sca= pd.DataFrame(x_test_sca, columns=x_test.columns)

# %%
x_train_sca.describe()
# Out:
#                   R            2B            3B            HR            BB  \
# count  2.400000e+01  2.400000e+01  2.400000e+01  2.400000e+01  2.400000e+01
# mean   6.291264e-16 -1.008453e-15  1.110223e-16  9.251859e-18  3.145632e-16
# std    1.021508e+00  1.021508e+00  1.021508e+00  1.021508e+00  1.021508e+00
# min   -1.918482e+00 -2.059949e+00 -1.734424e+00 -2.045970e+00 -1.530037e+00
# 25%   -5.459656e-01 -6.440097e-01 -8.893450e-01 -7.127355e-01 -8.212385e-01
# 50%    4.699451e-02  3.087718e-02  4.024186e-03 -8.385124e-02  2.419594e-02
# 75%    4.326259e-01  7.851625e-01  8.008129e-01  5.366479e-01  4.896119e-01
# max    3.355961e+00  1.751177e+00  1.742472e+00  2.381375e+00  1.800462e+00
#
#                  SO         SB            RA            ER           ERA  \
# count  2.400000e+01  24.000000  2.400000e+01  2.400000e+01  2.400000e+01
# mean  -6.846375e-16   0.000000  1.850372e-17 -6.106227e-16  2.590520e-16
# std    1.021508e+00   1.021508  1.021508e+00  1.021508e+00  1.021508e+00
# min   -2.447377e+00  -1.795642 -1.446153e+00 -1.642847e+00 -9.406470e-01
# 25%   -8.075921e-01  -0.606555 -7.676629e-01 -6.705228e-01 -9.406470e-01
# 50%    2.094896e-01   0.174159 -4.264794e-02  6.560889e-02 -7.235746e-02
# 75%    6.661386e-01   0.678621  6.474733e-01  6.521524e-01  7.959321e-01
# max    2.580374e+00   2.432224  2.415424e+00  2.561371e+00  2.532511e+00
#
#                 SHO         SV
# count  2.400000e+01  24.000000
# mean  -1.480297e-16   0.000000
# std    1.021508e+00   1.021508
# min   -1.939860e+00  -2.068556
# 25%   -4.928293e-01  -0.723994
# 50%    7.340011e-02   0.068952
# 75%    3.250576e-01   0.448187
# max    2.338318e+00   2.344363

# %%
x_train_sca.plot(kind='box',figsize=(20,30))
# Out:
# <Axes: >

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
x_train_sca.shape
# Out:
# (24, 12)

# %%
x_test_sca.shape
# Out:
# (6, 12)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score , confusion_matrix

# %% [markdown]
# .

# %%
svm = SVR()
svm.fit(x_train_sca,y_train)
y_pred1 = svm.predict(x_test_sca)
svm1 = metrics.r2_score(y_test,y_pred1)
svm1
# Out:
# 0.18804933093411025

# %%
lr= LinearRegression()
lr.fit(x_train_sca,y_train)
y_pred2 = lr.predict(x_test_sca)
lr2 = metrics.r2_score(y_test,y_pred2)
lr2
# Out:
# 0.9288086135113769

# %%
rfr= RandomForestRegressor()
rfr.fit(x_train_sca,y_train)
y_pred3 = rfr.predict(x_test_sca)
rfr3 = metrics.r2_score(y_test,y_pred3)
rfr3
# Out:
# 0.6438470224603339

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train_sca,y_train)
xxyy= gbr.predict(x_test_sca)
gbr4 = metrics.r2_score(y_test,xxyy)
gbr4
# Out:
# 0.5269317008406713

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .
